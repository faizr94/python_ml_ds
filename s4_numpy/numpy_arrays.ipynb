# %%
import numpy as np

# %%
# 2d matrices
my_matrix = [[1,2,3], [4,5,6], [7,8,9]]

# %%
my_matrix

# %%
np.array(my_matrix)

# %% [markdown]
# ### useful np methods

# %%
np.arange(0,10)

# %%
# up to but not including 10
np.arange(0,10,2)

# %%
np.zeros(5)

# %%
# rows, cols
np.zeros((2,5))

# %%
np.ones((3,4))

# %%
np.linspace(0,10,5)

# %%
# square matrix
np.eye(3)

# %% [markdown]
# ### Creating random distriutions of data

# %%
np.random.rand(1,2)

# %%
# standard normal distribution
np.random.randn(10)

# %%
np.random.randn(2,3)

# %%
# random integers
np.random.randint(0,100)

# %%
np.random.randint(0,100,3)

# %%
np.random.randint(0,100,(2,3))

# %% [markdown]
# set seed

# %%
# Seed allows you to set a particular set of random numbers
# 42 here is just an arbitrary number 
np.random.seed(42)
np.random.rand(4)

# %% [markdown]
# Some useful attributes and method calls

# %%
arr = np.arange(0,25)

# %%
arr.reshape(5,5)

# %%
ranarr = np.random.randint(0, 101, 10)

# %%
ranarr

# %%
ranarr.max()

# %%
ranarr.min()

# %%
# Index of the min number
ranarr.argmin()

# %%
ranarr.dtype

# %%
arr

# %%
arr.shape

# %%
arr = arr.reshape(5,5)
arr.shape
