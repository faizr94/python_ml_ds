# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Text/String Method Calls

# %%
names = pd.Series(['andrew', 'bobo', 'claire', 'david', '5'])
names

# %%
names.str.upper()

# %% [markdown]
# -> Stacking string calls

# %%
messy_names = pd.Series(['andrew    ', "bo;bo", "   claire "])
messy_names

# %%
# cleaning this up which is to remove the semicolon first 
messy_names.str.replace(";", "").str.strip().str.capitalize()
